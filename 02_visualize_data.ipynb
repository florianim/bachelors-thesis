# %%
import pandas as pd
import matplotlib.pyplot as plt
from shap_flow_util import read_csv_incl_timeindex

# %% [markdown]
# ## Visualize Data

# %%
version = 'v5'
X = read_csv_incl_timeindex('./data/{}/X_full.csv'.format(version))
y = read_csv_incl_timeindex('./data/{}/y_full.csv'.format(version))

# %% [markdown]
# ### input features

# %%
X.columns
# Out:
# Index(['carbon_price', 'gas_price', 'oil_price', 'solar_da', 'wind_da',
#        'load_da', 'nuclear_avail', 'generation_da', 'temp_mean',
#        'temp_mean_7d_avg', 'solar_da_ramp', 'wind_da_ramp', 'load_da_ramp',
#        'generation_da_ramp', 'month', 'dayofyear_sin', 'dayofyear_cos',
#        'hour_sin', 'hour_cos', 'day_of_week'],
#       dtype='object')

# %%
y.columns
# Out:
# Index(['price_da'], dtype='object')

# %%
X.plot(subplots=True, layout=(11,2), figsize=(22,22))
plt.tight_layout()
plt.show()

# %% [markdown]
# ### target: day-ahead price

# %%
y
# Out:
#                            price_da
# timestamp
# 2015-01-04 23:00:00+00:00     36.56
# 2015-01-05 00:00:00+00:00     34.94
# 2015-01-05 01:00:00+00:00     32.19
# 2015-01-05 02:00:00+00:00     23.53
# 2015-01-05 03:00:00+00:00     22.92
# ...                             ...
# 2023-12-31 19:00:00+00:00     16.43
# 2023-12-31 20:00:00+00:00      8.16
# 2023-12-31 21:00:00+00:00     10.68
# 2023-12-31 22:00:00+00:00      3.64
# 2023-12-31 23:00:00+00:00      0.10
#
# [75686 rows x 1 columns]

# %%
g = y.plot(figsize=(26,10))
#g = y.rolling(window='7d').mean().plot(figsize=(26, 10))
